# %%
import requests
import json
from pprint import pprint

url= " https://data.cdc.gov/resource/hiea-rbwm.json"
response= requests.get(url)
print(response.url)
# Out:
# https://data.cdc.gov/resource/hiea-rbwm.json

# %%
data = response.json()
pprint(data)
# Out:
# [{'countyfips': '1001',
#   'date': '01JAN2001',
#   'o3_max_pred': '31.939058',
#   'o3_mean_pred': '31.680858583',
#   'o3_med_pred': '31.691988',
#   'o3_pop_pred': '31.671226222',
#   'statefips': '1',
#   'year': '2001'},
#  {'countyfips': '1003',
#   'date': '01JAN2001',
#   'o3_max_pred': '33.646855',
#   'o3_mean_pred': '32.994774935',
#   'o3_med_pred': '33.170271',
#   'o3_pop_pred': '32.935069796',
#   'statefips': '1',
#   'year': '2001'},
#  {'countyfips': '1005',
#   'date': '01JAN2001',
#   'o3_max_pred': '34.288917',
#   'o3_mean_pred': '34.077953778',
#   'o3_med_pred': '34.068507',
#   'o3_pop_pred': '34.086630601',
#   'statefips': '1',
#   'year': '2001'},
#  {'countyfips': '1007',
#   'date': '01JAN2001',
#   'o3_max_pred': '30.349767',
#   'o3_mean_pred': '29.93175575',
#   'o3_med_pred': '30.036093',
#   'o3_pop_pred': '29.991733426',
#   'statefips': '1',
#   'year': '2001'},
#  {'countyfips': '1009',
#   'date': '01JAN2001',
#   'o3_max_pred': '26.472655',
# ...
