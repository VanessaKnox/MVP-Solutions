# %%
pip install sodapy
# Out:
# Requirement already satisfied: sodapy in c:\users\pooja\anaconda\anaconda\lib\site-packages (1.5.4)
# Requirement already satisfied: future>=0.17.1 in c:\users\pooja\anaconda\anaconda\lib\site-packages (from sodapy) (0.17.1)
# Requirement already satisfied: requests>=2.20.0 in c:\users\pooja\anaconda\anaconda\lib\site-packages (from sodapy) (2.22.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\pooja\anaconda\anaconda\lib\site-packages (from requests>=2.20.0->sodapy) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\pooja\anaconda\anaconda\lib\site-packages (from requests>=2.20.0->sodapy) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\pooja\anaconda\anaconda\lib\site-packages (from requests>=2.20.0->sodapy) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pooja\anaconda\anaconda\lib\site-packages (from requests>=2.20.0->sodapy) (2019.6.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import json
from pprint import pprint
import os
import pandas as pd
import sodapy
import numpy as np

url= " https://data.cdc.gov/resource/hiea-rbwm.json?year=2012"
response= requests.get(url)
print(response.url)


import matplotlib.pyplot as plt
import os
import gmaps

from config import gkey
gmaps.configure(api_key=gkey)
print("All dependencies imported properly.")
# Out:
# https://data.cdc.gov/resource/hiea-rbwm.json?year=2012
# All dependencies imported properly.

# %%
data = response.json()
pprint(data)

#print(response.status_code)
# Out:
# [{'countyfips': '1001',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.4737',
#   'o3_mean_pred': '31.285616667',
#   'o3_med_pred': '31.3134',
#   'o3_pop_pred': '31.23864505',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1003',
#   'date': '01JAN2012',
#   'o3_max_pred': '37.3396',
#   'o3_mean_pred': '32.992025806',
#   'o3_med_pred': '32.8829',
#   'o3_pop_pred': '32.913068928',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1005',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.1515',
#   'o3_mean_pred': '31.615122222',
#   'o3_med_pred': '31.506',
#   'o3_pop_pred': '31.592601868',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1007',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.1958',
#   'o3_mean_pred': '32.0757',
#   'o3_med_pred': '32.08455',
#   'o3_pop_pred': '32.052927462',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1009',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.0849',
#   'o3_mean_pred': '31.743422222',
#   'o3_med_pred': '31.7276',
#   'o3_pop_pred': '31.725956034',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1011',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.8021',
#   'o3_mean_pred': '32.725033333',
#   'o3_med_pred': '32.7643',
#   'o3_pop_pred': '32.768452941',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1013',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.2995',
#   'o3_mean_pred': '31.997644444',
#   'o3_med_pred': '32.0255',
#   'o3_pop_pred': '32.027982437',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1015',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.2108',
#   'o3_mean_pred': '32.628916129',
#   'o3_med_pred': '32.6968',
#   'o3_pop_pred': '32.649500641',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1017',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.9039',
#   'o3_mean_pred': '31.577677778',
#   'o3_med_pred': '31.5972',
#   'o3_pop_pred': '31.614195739',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1019',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.1628',
#   'o3_mean_pred': '32.29785',
#   'o3_med_pred': '32.22335',
#   'o3_pop_pred': '32.323501216',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1021',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.9265',
#   'o3_mean_pred': '31.758277778',
#   'o3_med_pred': '31.8213',
#   'o3_pop_pred': '31.771585526',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1023',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.3187',
#   'o3_mean_pred': '32.18795',
#   'o3_med_pred': '32.16695',
#   'o3_pop_pred': '32.177005181',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1025',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.0291',
#   'o3_mean_pred': '31.608444444',
#   'o3_med_pred': '31.7804',
#   'o3_pop_pred': '31.629475849',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1027',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.734',
#   'o3_mean_pred': '32.269425',
#   'o3_med_pred': '32.2169',
#   'o3_pop_pred': '32.35660735',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1029',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.4319',
#   'o3_mean_pred': '33.019425',
#   'o3_med_pred': '33.05225',
#   'o3_pop_pred': '32.969418895',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1031',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.7406',
#   'o3_mean_pred': '31.384271429',
#   'o3_med_pred': '31.3245',
#   'o3_pop_pred': '31.371009324',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1033',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.3588',
#   'o3_mean_pred': '30.993428571',
#   'o3_med_pred': '30.95725',
#   'o3_pop_pred': '31.00037408',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1035',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.748',
#   'o3_mean_pred': '31.31934',
#   'o3_med_pred': '31.2192',
#   'o3_pop_pred': '31.27305858',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1037',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.9314',
#   'o3_mean_pred': '31.6657',
#   'o3_med_pred': '31.6797',
#   'o3_pop_pred': '31.672304099',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1039',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.2605',
#   'o3_mean_pred': '31.756735714',
#   'o3_med_pred': '31.754',
#   'o3_pop_pred': '31.713747361',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1041',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.5093',
#   'o3_mean_pred': '31.9842',
#   'o3_med_pred': '31.97515',
#   'o3_pop_pred': '32.001047922',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1043',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.8784',
#   'o3_mean_pred': '31.600627778',
#   'o3_med_pred': '31.5971',
#   'o3_pop_pred': '31.570893136',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1045',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.33',
#   'o3_mean_pred': '31.117021429',
#   'o3_med_pred': '31.0919',
#   'o3_pop_pred': '31.120450958',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1047',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.7568',
#   'o3_mean_pred': '31.479906667',
#   'o3_med_pred': '31.4433',
#   'o3_pop_pred': '31.463341175',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1049',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.2939',
#   'o3_mean_pred': '31.961614286',
#   'o3_med_pred': '31.90945',
#   'o3_pop_pred': '31.949147633',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1051',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.4647',
#   'o3_mean_pred': '31.18066',
#   'o3_med_pred': '31.2331',
#   'o3_pop_pred': '31.180574621',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1053',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.1784',
#   'o3_mean_pred': '30.612144444',
#   'o3_med_pred': '30.5978',
#   'o3_pop_pred': '30.633652606',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1055',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.0351',
#   'o3_mean_pred': '31.683936667',
#   'o3_med_pred': '31.66365',
#   'o3_pop_pred': '31.690819763',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1057',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.0981',
#   'o3_mean_pred': '32.01732',
#   'o3_med_pred': '32.0106',
#   'o3_pop_pred': '32.011918885',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1059',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.5901',
#   'o3_mean_pred': '31.203122222',
#   'o3_med_pred': '31.2037',
#   'o3_pop_pred': '31.242858772',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1061',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.7223',
#   'o3_mean_pred': '31.406916667',
#   'o3_med_pred': '31.4031',
#   'o3_pop_pred': '31.413150224',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1063',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.9486',
#   'o3_mean_pred': '31.823133333',
#   'o3_med_pred': '31.7728',
#   'o3_pop_pred': '31.815537844',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1065',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.7427',
#   'o3_mean_pred': '31.63185',
#   'o3_med_pred': '31.65935',
#   'o3_pop_pred': '31.607608617',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1067',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.1237',
#   'o3_mean_pred': '30.844483333',
#   'o3_med_pred': '30.849',
#   'o3_pop_pred': '30.913322217',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1069',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.221',
#   'o3_mean_pred': '31.00655',
#   'o3_med_pred': '31.0271',
#   'o3_pop_pred': '31.023054412',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1071',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.6311',
#   'o3_mean_pred': '32.267945455',
#   'o3_med_pred': '32.2186',
#   'o3_pop_pred': '32.269788989',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1073',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.0869',
#   'o3_mean_pred': '31.225568712',
#   'o3_med_pred': '31.1667',
#   'o3_pop_pred': '31.257315264',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1075',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.0155',
#   'o3_mean_pred': '31.8661',
#   'o3_med_pred': '31.8313',
#   'o3_pop_pred': '31.880751181',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1077',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.5563',
#   'o3_mean_pred': '31.14555',
#   'o3_med_pred': '31.14305',
#   'o3_pop_pred': '31.16190998',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1079',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.4756',
#   'o3_mean_pred': '31.180088889',
#   'o3_med_pred': '31.1781',
#   'o3_pop_pred': '31.162580754',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1081',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.3069',
#   'o3_mean_pred': '31.930518519',
#   'o3_med_pred': '31.9237',
#   'o3_pop_pred': '31.928000698',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1083',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.4421',
#   'o3_mean_pred': '31.24595',
#   'o3_med_pred': '31.251',
#   'o3_pop_pred': '31.24969507',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1085',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.3155',
#   'o3_mean_pred': '32.063',
#   'o3_med_pred': '32.06335',
#   'o3_pop_pred': '32.076259147',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1087',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.6066',
#   'o3_mean_pred': '32.208216667',
#   'o3_med_pred': '32.1832',
#   'o3_pop_pred': '32.18314587',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1089',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.9169',
#   'o3_mean_pred': '31.383865753',
#   'o3_med_pred': '31.3679',
#   'o3_pop_pred': '31.404122259',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1091',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.8938',
#   'o3_mean_pred': '31.639483333',
#   'o3_med_pred': '31.59935',
#   'o3_pop_pred': '31.590408789',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1093',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.9345',
#   'o3_mean_pred': '31.7163625',
#   'o3_med_pred': '31.7384',
#   'o3_pop_pred': '31.738638026',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1095',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.9851',
#   'o3_mean_pred': '31.713333333',
#   'o3_med_pred': '31.7054',
#   'o3_pop_pred': '31.714264579',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1097',
#   'date': '01JAN2012',
#   'o3_max_pred': '34.9843',
#   'o3_mean_pred': '31.457159649',
#   'o3_med_pred': '31.35125',
#   'o3_pop_pred': '31.576980491',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1099',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.8164',
#   'o3_mean_pred': '31.5119',
#   'o3_med_pred': '31.5847',
#   'o3_pop_pred': '31.452985638',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1101',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.774',
#   'o3_mean_pred': '31.610838462',
#   'o3_med_pred': '31.5186',
#   'o3_pop_pred': '31.597781886',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1103',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.547',
#   'o3_mean_pred': '31.251759259',
#   'o3_med_pred': '31.2338',
#   'o3_pop_pred': '31.265050033',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1105',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.025',
#   'o3_mean_pred': '31.8095',
#   'o3_med_pred': '31.7263',
#   'o3_pop_pred': '31.878134142',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1107',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.0456',
#   'o3_mean_pred': '31.83618',
#   'o3_med_pred': '31.8254',
#   'o3_pop_pred': '31.85799845',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1109',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.4656',
#   'o3_mean_pred': '31.8808875',
#   'o3_med_pred': '31.8462',
#   'o3_pop_pred': '31.822041159',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1111',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.5012',
#   'o3_mean_pred': '31.965083333',
#   'o3_med_pred': '31.92015',
#   'o3_pop_pred': '31.947041841',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1113',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.6546',
#   'o3_mean_pred': '32.037553846',
#   'o3_med_pred': '32.0226',
#   'o3_pop_pred': '32.028342197',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1115',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.7966',
#   'o3_mean_pred': '31.591784615',
#   'o3_med_pred': '31.5963',
#   'o3_pop_pred': '31.594290578',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1117',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.0322',
#   'o3_mean_pred': '31.48426875',
#   'o3_med_pred': '31.4719',
#   'o3_pop_pred': '31.463036502',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1119',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.828',
#   'o3_mean_pred': '32.355725',
#   'o3_med_pred': '32.27465',
#   'o3_pop_pred': '32.284460067',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1121',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.9068',
#   'o3_mean_pred': '32.112854545',
#   'o3_med_pred': '31.9868',
#   'o3_pop_pred': '32.116022803',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1123',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.7598',
#   'o3_mean_pred': '31.61295',
#   'o3_med_pred': '31.6482',
#   'o3_pop_pred': '31.590039485',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1125',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.2874',
#   'o3_mean_pred': '31.803440426',
#   'o3_med_pred': '31.791',
#   'o3_pop_pred': '31.818648612',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1127',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.2728',
#   'o3_mean_pred': '32.023083333',
#   'o3_med_pred': '31.99215',
#   'o3_pop_pred': '32.009147106',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1129',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.4947',
#   'o3_mean_pred': '32.76444',
#   'o3_med_pred': '32.7087',
#   'o3_pop_pred': '32.703397497',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1131',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.9901',
#   'o3_mean_pred': '31.7943',
#   'o3_med_pred': '31.85015',
#   'o3_pop_pred': '31.83825946',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '1133',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.8767',
#   'o3_mean_pred': '31.758257143',
#   'o3_med_pred': '31.8356',
#   'o3_pop_pred': '31.749575711',
#   'statefips': '1',
#   'year': '2012'},
#  {'countyfips': '4001',
#   'date': '01JAN2012',
#   'o3_max_pred': '35.4517',
#   'o3_mean_pred': '34.24315',
#   'o3_med_pred': '34.4933',
#   'o3_pop_pred': '34.259404',
#   'statefips': '4',
#   'year': '2012'},
#  {'countyfips': '4003',
#   'date': '01JAN2012',
#   'o3_max_pred': '35.6666',
#   'o3_mean_pred': '35.12791875',
#   'o3_med_pred': '35.19445',
#   'o3_pop_pred': '35.136648507',
#   'statefips': '4',
#   'year': '2012'},
#  {'countyfips': '4005',
#   'date': '01JAN2012',
#   'o3_max_pred': '37.5627',
#   'o3_mean_pred': '36.261732143',
#   'o3_med_pred': '36.47915',
#   'o3_pop_pred': '36.23061304',
#   'statefips': '4',
#   'year': '2012'},
#  {'countyfips': '4007',
#   'date': '01JAN2012',
#   'o3_max_pred': '37.7672',
#   'o3_mean_pred': '36.1376375',
#   'o3_med_pred': '35.92375',
#   'o3_pop_pred': '36.219763645',
#   'statefips': '4',
#   'year': '2012'},
#  {'countyfips': '4009',
#   'date': '01JAN2012',
#   'o3_max_pred': '34.8483',
#   'o3_mean_pred': '34.735122222',
#   'o3_med_pred': '34.7538',
#   'o3_pop_pred': '34.739537993',
#   'statefips': '4',
#   'year': '2012'},
#  {'countyfips': '4011',
#   'date': '01JAN2012',
#   'o3_max_pred': '34.9089',
#   'o3_mean_pred': '34.606166667',
#   'o3_med_pred': '34.8185',
#   'o3_pop_pred': '34.597411793',
#   'statefips': '4',
#   'year': '2012'},
#  {'countyfips': '4012',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.9879',
#   'o3_mean_pred': '33.190188889',
#   'o3_med_pred': '33.1718',
#   'o3_pop_pred': '33.244793904',
#   'statefips': '4',
#   'year': '2012'},
#  {'countyfips': '4013',
#   'date': '01JAN2012',
#   'o3_max_pred': '37.1773',
#   'o3_mean_pred': '31.833406114',
#   'o3_med_pred': '31.72395',
#   'o3_pop_pred': '31.846865269',
#   'statefips': '4',
#   'year': '2012'},
#  {'countyfips': '4015',
#   'date': '01JAN2012',
#   'o3_max_pred': '35.7943',
#   'o3_mean_pred': '33.845583721',
#   'o3_med_pred': '33.85',
#   'o3_pop_pred': '33.967690055',
#   'statefips': '4',
#   'year': '2012'},
#  {'countyfips': '4017',
#   'date': '01JAN2012',
#   'o3_max_pred': '37.0207',
#   'o3_mean_pred': '33.77683871',
#   'o3_med_pred': '33.8245',
#   'o3_pop_pred': '33.622616254',
#   'statefips': '4',
#   'year': '2012'},
#  {'countyfips': '4019',
#   'date': '01JAN2012',
#   'o3_max_pred': '35.0528',
#   'o3_mean_pred': '33.247106224',
#   'o3_med_pred': '33.0171',
#   'o3_pop_pred': '33.229887731',
#   'statefips': '4',
#   'year': '2012'},
#  {'countyfips': '4021',
#   'date': '01JAN2012',
#   'o3_max_pred': '36.1624',
#   'o3_mean_pred': '33.906025333',
#   'o3_med_pred': '34.2338',
#   'o3_pop_pred': '34.021375385',
#   'statefips': '4',
#   'year': '2012'},
#  {'countyfips': '4023',
#   'date': '01JAN2012',
#   'o3_max_pred': '35.1861',
#   'o3_mean_pred': '34.8351',
#   'o3_med_pred': '34.82915',
#   'o3_pop_pred': '34.804798539',
#   'statefips': '4',
#   'year': '2012'},
#  {'countyfips': '4025',
#   'date': '01JAN2012',
#   'o3_max_pred': '38.382',
#   'o3_mean_pred': '37.685752381',
#   'o3_med_pred': '37.7784',
#   'o3_pop_pred': '37.709014805',
#   'statefips': '4',
#   'year': '2012'},
#  {'countyfips': '4027',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.857',
#   'o3_mean_pred': '29.580072727',
#   'o3_med_pred': '29.5085',
#   'o3_pop_pred': '29.295147893',
#   'statefips': '4',
#   'year': '2012'},
#  {'countyfips': '5001',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.5286',
#   'o3_mean_pred': '31.3268875',
#   'o3_med_pred': '31.3685',
#   'o3_pop_pred': '31.365929339',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5003',
#   'date': '01JAN2012',
#   'o3_max_pred': '30.986',
#   'o3_mean_pred': '30.8359',
#   'o3_med_pred': '30.7971',
#   'o3_pop_pred': '30.836341074',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5005',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.954',
#   'o3_mean_pred': '32.879777778',
#   'o3_med_pred': '32.8965',
#   'o3_pop_pred': '32.876759042',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5007',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.3557',
#   'o3_mean_pred': '33.062955102',
#   'o3_med_pred': '33.0716',
#   'o3_pop_pred': '33.055854895',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5009',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.4589',
#   'o3_mean_pred': '33.321314286',
#   'o3_med_pred': '33.292',
#   'o3_pop_pred': '33.313827255',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5011',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.1638',
#   'o3_mean_pred': '30.99526',
#   'o3_med_pred': '30.9511',
#   'o3_pop_pred': '31.000110141',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5013',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.6054',
#   'o3_mean_pred': '31.44245',
#   'o3_med_pred': '31.44245',
#   'o3_pop_pred': '31.449431837',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5015',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.5343',
#   'o3_mean_pred': '33.38892',
#   'o3_med_pred': '33.3713',
#   'o3_pop_pred': '33.384928667',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5017',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.5973',
#   'o3_mean_pred': '31.444925',
#   'o3_med_pred': '31.3164',
#   'o3_pop_pred': '31.458077288',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5019',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.9616',
#   'o3_mean_pred': '33.14284',
#   'o3_med_pred': '32.9331',
#   'o3_pop_pred': '33.140916699',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5021',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.6619',
#   'o3_mean_pred': '32.506883333',
#   'o3_med_pred': '32.50975',
#   'o3_pop_pred': '32.524299372',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5023',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.8088',
#   'o3_mean_pred': '32.610642857',
#   'o3_med_pred': '32.67',
#   'o3_pop_pred': '32.603989958',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5025',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.3366',
#   'o3_mean_pred': '31.26645',
#   'o3_med_pred': '31.26645',
#   'o3_pop_pred': '31.257561158',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5027',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.6076',
#   'o3_mean_pred': '33.35832',
#   'o3_med_pred': '33.3175',
#   'o3_pop_pred': '33.353612822',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5029',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.9013',
#   'o3_mean_pred': '32.719116667',
#   'o3_med_pred': '32.721',
#   'o3_pop_pred': '32.7402018',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5031',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.2453',
#   'o3_mean_pred': '32.059164706',
#   'o3_med_pred': '32.0582',
#   'o3_pop_pred': '32.053885315',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5033',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.8147',
#   'o3_mean_pred': '33.608845455',
#   'o3_med_pred': '33.6734',
#   'o3_pop_pred': '33.599965787',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5035',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.3688',
#   'o3_mean_pred': '30.94472',
#   'o3_med_pred': '30.90375',
#   'o3_pop_pred': '30.927235686',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5037',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.5133',
#   'o3_mean_pred': '31.387516667',
#   'o3_med_pred': '31.38975',
#   'o3_pop_pred': '31.388366088',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5039',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.8844',
#   'o3_mean_pred': '31.728066667',
#   'o3_med_pred': '31.7808',
#   'o3_pop_pred': '31.65440722',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5041',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.0354',
#   'o3_mean_pred': '30.64432',
#   'o3_med_pred': '30.603',
#   'o3_pop_pred': '30.625378967',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5043',
#   'date': '01JAN2012',
#   'o3_max_pred': '30.8254',
#   'o3_mean_pred': '30.71206',
#   'o3_med_pred': '30.7031',
#   'o3_pop_pred': '30.73214561',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5045',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.8535',
#   'o3_mean_pred': '32.428676',
#   'o3_med_pred': '32.4288',
#   'o3_pop_pred': '32.42967499',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5047',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.2419',
#   'o3_mean_pred': '33.1776',
#   'o3_med_pred': '33.2094',
#   'o3_pop_pred': '33.164716006',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5049',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.9787',
#   'o3_mean_pred': '32.8876',
#   'o3_med_pred': '32.8876',
#   'o3_pop_pred': '32.890047685',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5051',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.5924',
#   'o3_mean_pred': '32.634115',
#   'o3_med_pred': '32.55285',
#   'o3_pop_pred': '32.686315737',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5053',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.8115',
#   'o3_mean_pred': '31.601875',
#   'o3_med_pred': '31.6404',
#   'o3_pop_pred': '31.592560785',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5055',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.702',
#   'o3_mean_pred': '32.382366667',
#   'o3_med_pred': '32.3927',
#   'o3_pop_pred': '32.330951701',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5057',
#   'date': '01JAN2012',
#   'o3_max_pred': '34.2211',
#   'o3_mean_pred': '33.70066',
#   'o3_med_pred': '33.6658',
#   'o3_pop_pred': '33.757861427',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5059',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.3351',
#   'o3_mean_pred': '32.206285714',
#   'o3_med_pred': '31.989',
#   'o3_pop_pred': '32.246049191',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5061',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.8028',
#   'o3_mean_pred': '33.5487',
#   'o3_med_pred': '33.5951',
#   'o3_pop_pred': '33.540302618',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5063',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.4141',
#   'o3_mean_pred': '32.2797875',
#   'o3_med_pred': '32.27135',
#   'o3_pop_pred': '32.292866491',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5065',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.0206',
#   'o3_mean_pred': '32.810825',
#   'o3_med_pred': '32.75905',
#   'o3_pop_pred': '32.845690618',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5067',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.1704',
#   'o3_mean_pred': '31.94978',
#   'o3_med_pred': '31.965',
#   'o3_pop_pred': '31.927670623',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5069',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.4067',
#   'o3_mean_pred': '31.0723625',
#   'o3_med_pred': '31.0676',
#   'o3_pop_pred': '31.075860775',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5071',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.7415',
#   'o3_mean_pred': '33.14525',
#   'o3_med_pred': '33.0153',
#   'o3_pop_pred': '33.159001731',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5073',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.9745',
#   'o3_mean_pred': '32.90635',
#   'o3_med_pred': '32.90635',
#   'o3_pop_pred': '32.922493839',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5075',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.5553',
#   'o3_mean_pred': '32.290883333',
#   'o3_med_pred': '32.26915',
#   'o3_pop_pred': '32.341234608',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5077',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.1945',
#   'o3_mean_pred': '31.061825',
#   'o3_med_pred': '31.0518',
#   'o3_pop_pred': '31.022320462',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5079',
#   'date': '01JAN2012',
#   'o3_max_pred': '30.7763',
#   'o3_mean_pred': '30.670475',
#   'o3_med_pred': '30.706',
#   'o3_pop_pred': '30.669614299',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5081',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.3447',
#   'o3_mean_pred': '32.08875',
#   'o3_med_pred': '32.09815',
#   'o3_pop_pred': '32.110865705',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5083',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.6904',
#   'o3_mean_pred': '33.17165',
#   'o3_med_pred': '33.0546',
#   'o3_pop_pred': '33.151893853',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5085',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.3002',
#   'o3_mean_pred': '31.9014875',
#   'o3_med_pred': '31.90545',
#   'o3_pop_pred': '31.939387567',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5087',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.6598',
#   'o3_mean_pred': '33.610675',
#   'o3_med_pred': '33.6036',
#   'o3_pop_pred': '33.608788096',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5089',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.1668',
#   'o3_mean_pred': '32.973775',
#   'o3_med_pred': '32.9703',
#   'o3_pop_pred': '32.959370282',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5091',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.3773',
#   'o3_mean_pred': '32.117075',
#   'o3_med_pred': '32.11265',
#   'o3_pop_pred': '32.165176621',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5093',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.3949',
#   'o3_mean_pred': '32.126258333',
#   'o3_med_pred': '32.12285',
#   'o3_pop_pred': '32.145204404',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5095',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.5001',
#   'o3_mean_pred': '31.3308',
#   'o3_med_pred': '31.3475',
#   'o3_pop_pred': '31.363145699',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5097',
#   'date': '01JAN2012',
#   'o3_max_pred': '35.2425',
#   'o3_mean_pred': '34.897233333',
#   'o3_med_pred': '35.1627',
#   'o3_pop_pred': '34.891202899',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5099',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.9897',
#   'o3_mean_pred': '33.851366667',
#   'o3_med_pred': '33.8195',
#   'o3_pop_pred': '33.900584828',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5101',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.9239',
#   'o3_mean_pred': '33.7508',
#   'o3_med_pred': '33.7508',
#   'o3_pop_pred': '33.754457335',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5103',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.9685',
#   'o3_mean_pred': '32.432816667',
#   'o3_med_pred': '32.42775',
#   'o3_pop_pred': '32.379846627',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5105',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.6148',
#   'o3_mean_pred': '32.507966667',
#   'o3_med_pred': '32.5263',
#   'o3_pop_pred': '32.469068597',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5107',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.1387',
#   'o3_mean_pred': '31.009566667',
#   'o3_med_pred': '31.0354',
#   'o3_pop_pred': '31.013545117',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5109',
#   'date': '01JAN2012',
#   'o3_max_pred': '35.0228',
#   'o3_mean_pred': '34.897733333',
#   'o3_med_pred': '34.9129',
#   'o3_pop_pred': '34.874556045',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5111',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.2007',
#   'o3_mean_pred': '31.907385714',
#   'o3_med_pred': '31.9143',
#   'o3_pop_pred': '31.894475792',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5113',
#   'date': '01JAN2012',
#   'o3_max_pred': '34.6984',
#   'o3_mean_pred': '33.378083333',
#   'o3_med_pred': '33.378',
#   'o3_pop_pred': '33.505506389',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5115',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.6724',
#   'o3_mean_pred': '32.982981818',
#   'o3_med_pred': '32.8748',
#   'o3_pop_pred': '32.949224954',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5117',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.5497',
#   'o3_mean_pred': '31.5294',
#   'o3_med_pred': '31.5265',
#   'o3_pop_pred': '31.53273891',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5119',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.3006',
#   'o3_mean_pred': '31.759722105',
#   'o3_med_pred': '31.7269',
#   'o3_pop_pred': '31.772177333',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5121',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.944',
#   'o3_mean_pred': '32.738',
#   'o3_med_pred': '32.7051',
#   'o3_pop_pred': '32.765558684',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5123',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.266',
#   'o3_mean_pred': '31.132016667',
#   'o3_med_pred': '31.1346',
#   'o3_pop_pred': '31.109479779',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5125',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.5183',
#   'o3_mean_pred': '31.800766667',
#   'o3_med_pred': '31.8308',
#   'o3_pop_pred': '31.792336407',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5127',
#   'date': '01JAN2012',
#   'o3_max_pred': '35.3492',
#   'o3_mean_pred': '35.155333333',
#   'o3_med_pred': '35.069',
#   'o3_pop_pred': '35.110033758',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5129',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.4408',
#   'o3_mean_pred': '33.218166667',
#   'o3_med_pred': '33.2255',
#   'o3_pop_pred': '33.181256486',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5131',
#   'date': '01JAN2012',
#   'o3_max_pred': '34.8016',
#   'o3_mean_pred': '34.107746154',
#   'o3_med_pred': '34.07165',
#   'o3_pop_pred': '34.120155995',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5133',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.4525',
#   'o3_mean_pred': '32.10255',
#   'o3_med_pred': '32.08455',
#   'o3_pop_pred': '32.037974851',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5135',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.9175',
#   'o3_mean_pred': '32.68655',
#   'o3_med_pred': '32.7478',
#   'o3_pop_pred': '32.654998888',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5137',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.8621',
#   'o3_mean_pred': '32.752133333',
#   'o3_med_pred': '32.7517',
#   'o3_pop_pred': '32.797097362',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5139',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.3995',
#   'o3_mean_pred': '31.83206',
#   'o3_med_pred': '31.8186',
#   'o3_pop_pred': '31.841007639',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5141',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.1675',
#   'o3_mean_pred': '32.94002',
#   'o3_med_pred': '32.9677',
#   'o3_pop_pred': '32.927421162',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5143',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.4172',
#   'o3_mean_pred': '33.127025',
#   'o3_med_pred': '33.0958',
#   'o3_pop_pred': '33.120919103',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5145',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.2767',
#   'o3_mean_pred': '31.917815385',
#   'o3_med_pred': '31.8891',
#   'o3_pop_pred': '31.90922049',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5147',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.678',
#   'o3_mean_pred': '31.5995',
#   'o3_med_pred': '31.5995',
#   'o3_pop_pred': '31.580988705',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '5149',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.0162',
#   'o3_mean_pred': '32.8229',
#   'o3_med_pred': '32.8067',
#   'o3_pop_pred': '32.812717201',
#   'statefips': '5',
#   'year': '2012'},
#  {'countyfips': '6001',
#   'date': '01JAN2012',
#   'o3_max_pred': '21.8066',
#   'o3_mean_pred': '20.416055833',
#   'o3_med_pred': '20.30095',
#   'o3_pop_pred': '20.376053047',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6003',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.4047',
#   'o3_mean_pred': '31.4047',
#   'o3_med_pred': '31.4047',
#   'o3_pop_pred': '31.4047',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6005',
#   'date': '01JAN2012',
#   'o3_max_pred': '29.771',
#   'o3_mean_pred': '23.807422222',
#   'o3_med_pred': '23.4221',
#   'o3_pop_pred': '23.341685314',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6007',
#   'date': '01JAN2012',
#   'o3_max_pred': '28.6156',
#   'o3_mean_pred': '23.741988235',
#   'o3_med_pred': '22.7501',
#   'o3_pop_pred': '23.766468606',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6009',
#   'date': '01JAN2012',
#   'o3_max_pred': '29.8734',
#   'o3_mean_pred': '25.68656',
#   'o3_med_pred': '26.219',
#   'o3_pop_pred': '24.391989703',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6011',
#   'date': '01JAN2012',
#   'o3_max_pred': '22.2888',
#   'o3_mean_pred': '21.18008',
#   'o3_med_pred': '20.7269',
#   'o3_pop_pred': '21.131086372',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6013',
#   'date': '01JAN2012',
#   'o3_max_pred': '23.6451',
#   'o3_mean_pred': '21.063361538',
#   'o3_med_pred': '21.37375',
#   'o3_pop_pred': '20.922146611',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6015',
#   'date': '01JAN2012',
#   'o3_max_pred': '28.5597',
#   'o3_mean_pred': '28.254285714',
#   'o3_med_pred': '28.2278',
#   'o3_pop_pred': '28.304332073',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6017',
#   'date': '01JAN2012',
#   'o3_max_pred': '30.284',
#   'o3_mean_pred': '27.181106977',
#   'o3_med_pred': '28.6014',
#   'o3_pop_pred': '26.716391327',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6019',
#   'date': '01JAN2012',
#   'o3_max_pred': '40.5899',
#   'o3_mean_pred': '32.608725628',
#   'o3_med_pred': '32.4226',
#   'o3_pop_pred': '32.544025758',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6021',
#   'date': '01JAN2012',
#   'o3_max_pred': '22.7645',
#   'o3_mean_pred': '21.521933333',
#   'o3_med_pred': '21.29715',
#   'o3_pop_pred': '21.40556896',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6023',
#   'date': '01JAN2012',
#   'o3_max_pred': '28.4422',
#   'o3_mean_pred': '27.425846667',
#   'o3_med_pred': '27.61535',
#   'o3_pop_pred': '27.476038953',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6025',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.3291',
#   'o3_mean_pred': '27.783006452',
#   'o3_med_pred': '27.1314',
#   'o3_pop_pred': '27.48095026',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6027',
#   'date': '01JAN2012',
#   'o3_max_pred': '38.3879',
#   'o3_mean_pred': '35.686666667',
#   'o3_med_pred': '36.80855',
#   'o3_pop_pred': '35.501393972',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6029',
#   'date': '01JAN2012',
#   'o3_max_pred': '42.074',
#   'o3_mean_pred': '37.929250331',
#   'o3_med_pred': '38.933',
#   'o3_pop_pred': '37.887841393',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6031',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.2784',
#   'o3_mean_pred': '30.091007407',
#   'o3_med_pred': '30.0015',
#   'o3_pop_pred': '30.154902894',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6033',
#   'date': '01JAN2012',
#   'o3_max_pred': '23.6908',
#   'o3_mean_pred': '23.265893333',
#   'o3_med_pred': '23.2585',
#   'o3_pop_pred': '23.250827528',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6035',
#   'date': '01JAN2012',
#   'o3_max_pred': '30.3925',
#   'o3_mean_pred': '29.755455556',
#   'o3_med_pred': '29.7868',
#   'o3_pop_pred': '29.697414555',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6037',
#   'date': '01JAN2012',
#   'o3_max_pred': '38.2886',
#   'o3_mean_pred': '28.752322919',
#   'o3_med_pred': '28.0064',
#   'o3_pop_pred': '28.736205492',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6039',
#   'date': '01JAN2012',
#   'o3_max_pred': '39.1174',
#   'o3_mean_pred': '31.303043478',
#   'o3_med_pred': '29.7673',
#   'o3_pop_pred': '30.858142772',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6041',
#   'date': '01JAN2012',
#   'o3_max_pred': '25.0447',
#   'o3_mean_pred': '24.043652727',
#   'o3_med_pred': '24.2419',
#   'o3_pop_pred': '24.055484793',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6043',
#   'date': '01JAN2012',
#   'o3_max_pred': '37.9017',
#   'o3_mean_pred': '34.406233333',
#   'o3_med_pred': '34.15805',
#   'o3_pop_pred': '34.063959821',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6045',
#   'date': '01JAN2012',
#   'o3_max_pred': '24.4668',
#   'o3_mean_pred': '21.99875',
#   'o3_med_pred': '22.21855',
#   'o3_pop_pred': '21.848627875',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6047',
#   'date': '01JAN2012',
#   'o3_max_pred': '27.8154',
#   'o3_mean_pred': '22.271355102',
#   'o3_med_pred': '22.6374',
#   'o3_pop_pred': '22.173809071',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6049',
#   'date': '01JAN2012',
#   'o3_max_pred': '30.2928',
#   'o3_mean_pred': '28.980575',
#   'o3_med_pred': '29.38225',
#   'o3_pop_pred': '29.0189586',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6051',
#   'date': '01JAN2012',
#   'o3_max_pred': '37.8614',
#   'o3_mean_pred': '36.466966667',
#   'o3_med_pred': '36.8173',
#   'o3_pop_pred': '37.053767505',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6053',
#   'date': '01JAN2012',
#   'o3_max_pred': '34.8353',
#   'o3_mean_pred': '31.823770968',
#   'o3_med_pred': '31.5432',
#   'o3_pop_pred': '31.667704994',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6055',
#   'date': '01JAN2012',
#   'o3_max_pred': '25.1414',
#   'o3_mean_pred': '24.6099225',
#   'o3_med_pred': '24.86905',
#   'o3_pop_pred': '24.63262301',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6057',
#   'date': '01JAN2012',
#   'o3_max_pred': '30.7945',
#   'o3_mean_pred': '28.3193',
#   'o3_med_pred': '28.2378',
#   'o3_pop_pred': '28.419883153',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6059',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.7994',
#   'o3_mean_pred': '27.17139811',
#   'o3_med_pred': '26.3884',
#   'o3_pop_pred': '27.167382915',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6061',
#   'date': '01JAN2012',
#   'o3_max_pred': '30.4784',
#   'o3_mean_pred': '22.555094118',
#   'o3_med_pred': '20.8959',
#   'o3_pop_pred': '22.004722078',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6063',
#   'date': '01JAN2012',
#   'o3_max_pred': '30.4395',
#   'o3_mean_pred': '29.735457143',
#   'o3_med_pred': '29.7855',
#   'o3_pop_pred': '29.621007717',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6065',
#   'date': '01JAN2012',
#   'o3_max_pred': '37.9112',
#   'o3_mean_pred': '33.486190949',
#   'o3_med_pred': '33.8618',
#   'o3_pop_pred': '33.373625679',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6067',
#   'date': '01JAN2012',
#   'o3_max_pred': '22.2281',
#   'o3_mean_pred': '18.421010095',
#   'o3_med_pred': '18.114',
#   'o3_pop_pred': '18.408489518',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6069',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.6268',
#   'o3_mean_pred': '29.787281818',
#   'o3_med_pred': '29.5214',
#   'o3_pop_pred': '29.641783038',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6071',
#   'date': '01JAN2012',
#   'o3_max_pred': '37.4006',
#   'o3_mean_pred': '31.320619241',
#   'o3_med_pred': '31.1069',
#   'o3_pop_pred': '31.24245946',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6073',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.9607',
#   'o3_mean_pred': '27.415885646',
#   'o3_med_pred': '27.3521',
#   'o3_pop_pred': '27.607144784',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6075',
#   'date': '01JAN2012',
#   'o3_max_pred': '27.5613',
#   'o3_mean_pred': '21.528160714',
#   'o3_med_pred': '21.4564',
#   'o3_pop_pred': '21.515006991',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6077',
#   'date': '01JAN2012',
#   'o3_max_pred': '18.3947',
#   'o3_mean_pred': '14.90691223',
#   'o3_med_pred': '14.6577',
#   'o3_pop_pred': '14.936968436',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6079',
#   'date': '01JAN2012',
#   'o3_max_pred': '38.3069',
#   'o3_mean_pred': '32.766164151',
#   'o3_med_pred': '32.968',
#   'o3_pop_pred': '32.921789786',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6081',
#   'date': '01JAN2012',
#   'o3_max_pred': '27.3432',
#   'o3_mean_pred': '21.682048101',
#   'o3_med_pred': '21.6014',
#   'o3_pop_pred': '21.722976537',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6083',
#   'date': '01JAN2012',
#   'o3_max_pred': '40.301',
#   'o3_mean_pred': '35.106891011',
#   'o3_med_pred': '35.3775',
#   'o3_pop_pred': '35.096991139',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6085',
#   'date': '01JAN2012',
#   'o3_max_pred': '28.2635',
#   'o3_mean_pred': '22.30576371',
#   'o3_med_pred': '21.7665',
#   'o3_pop_pred': '22.329643683',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6087',
#   'date': '01JAN2012',
#   'o3_max_pred': '35.3032',
#   'o3_mean_pred': '32.454875',
#   'o3_med_pred': '32.45555',
#   'o3_pop_pred': '32.375262064',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6089',
#   'date': '01JAN2012',
#   'o3_max_pred': '28.4546',
#   'o3_mean_pred': '18.938345833',
#   'o3_med_pred': '17.9055',
#   'o3_pop_pred': '18.878522386',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6091',
#   'date': '01JAN2012',
#   'o3_max_pred': '30.2559',
#   'o3_mean_pred': '30.2559',
#   'o3_med_pred': '30.2559',
#   'o3_pop_pred': '30.2559',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6093',
#   'date': '01JAN2012',
#   'o3_max_pred': '25.8426',
#   'o3_mean_pred': '23.122621429',
#   'o3_med_pred': '22.9582',
#   'o3_pop_pred': '22.844022425',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6095',
#   'date': '01JAN2012',
#   'o3_max_pred': '24.1849',
#   'o3_mean_pred': '22.891429167',
#   'o3_med_pred': '22.9457',
#   'o3_pop_pred': '22.832643803',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6097',
#   'date': '01JAN2012',
#   'o3_max_pred': '24.8407',
#   'o3_mean_pred': '23.137106061',
#   'o3_med_pred': '22.768',
#   'o3_pop_pred': '23.097903093',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6099',
#   'date': '01JAN2012',
#   'o3_max_pred': '21.8169',
#   'o3_mean_pred': '15.812379787',
#   'o3_med_pred': '15.22955',
#   'o3_pop_pred': '15.863848612',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6101',
#   'date': '01JAN2012',
#   'o3_max_pred': '20.9759',
#   'o3_mean_pred': '19.722066667',
#   'o3_med_pred': '19.5736',
#   'o3_pop_pred': '19.720004536',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6103',
#   'date': '01JAN2012',
#   'o3_max_pred': '25.9835',
#   'o3_mean_pred': '21.2596',
#   'o3_med_pred': '20.9224',
#   'o3_pop_pred': '21.066772584',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6105',
#   'date': '01JAN2012',
#   'o3_max_pred': '25.5271',
#   'o3_mean_pred': '23.64786',
#   'o3_med_pred': '23.8456',
#   'o3_pop_pred': '23.262669607',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6107',
#   'date': '01JAN2012',
#   'o3_max_pred': '39.9845',
#   'o3_mean_pred': '35.539916667',
#   'o3_med_pred': '35.41545',
#   'o3_pop_pred': '35.548904003',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6109',
#   'date': '01JAN2012',
#   'o3_max_pred': '35.4233',
#   'o3_mean_pred': '29.584527273',
#   'o3_med_pred': '29.3146',
#   'o3_pop_pred': '29.858629013',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6111',
#   'date': '01JAN2012',
#   'o3_max_pred': '39.7084',
#   'o3_mean_pred': '34.894139884',
#   'o3_med_pred': '34.9774',
#   'o3_pop_pred': '34.847260384',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6113',
#   'date': '01JAN2012',
#   'o3_max_pred': '22.6321',
#   'o3_mean_pred': '20.006563415',
#   'o3_med_pred': '20.3829',
#   'o3_pop_pred': '19.99095226',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '6115',
#   'date': '01JAN2012',
#   'o3_max_pred': '28.8162',
#   'o3_mean_pred': '21.1624',
#   'o3_med_pred': '20.0842',
#   'o3_pop_pred': '21.008259848',
#   'statefips': '6',
#   'year': '2012'},
#  {'countyfips': '8001',
#   'date': '01JAN2012',
#   'o3_max_pred': '29.951',
#   'o3_mean_pred': '25.525273196',
#   'o3_med_pred': '25.3132',
#   'o3_pop_pred': '25.590412236',
#   'statefips': '8',
#   'year': '2012'},
#  {'countyfips': '8003',
#   'date': '01JAN2012',
#   'o3_max_pred': '34.5276',
#   'o3_mean_pred': '34.394425',
#   'o3_med_pred': '34.4077',
#   'o3_pop_pred': '34.444019482',
#   'statefips': '8',
#   'year': '2012'},
#  {'countyfips': '8005',
#   'date': '01JAN2012',
#   'o3_max_pred': '29.8193',
#   'o3_mean_pred': '24.563408163',
#   'o3_med_pred': '24.3011',
#   'o3_pop_pred': '24.650649116',
#   'statefips': '8',
#   'year': '2012'},
#  {'countyfips': '8007',
#   'date': '01JAN2012',
#   'o3_max_pred': '37.531',
#   'o3_mean_pred': '37.3884',
#   'o3_med_pred': '37.4086',
#   'o3_pop_pred': '37.394696524',
#   'statefips': '8',
#   'year': '2012'},
#  {'countyfips': '8009',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.7448',
#   'o3_mean_pred': '32.7404',
#   'o3_med_pred': '32.7404',
#   'o3_pop_pred': '32.740037592',
#   'statefips': '8',
#   'year': '2012'},
#  {'countyfips': '8011',
#   'date': '01JAN2012',
#   'o3_max_pred': '30.4617',
#   'o3_mean_pred': '30.4617',
#   'o3_med_pred': '30.4617',
#   'o3_pop_pred': '30.4617',
#   'statefips': '8',
#   'year': '2012'},
#  {'countyfips': '8013',
#   'date': '01JAN2012',
#   'o3_max_pred': '39.0962',
#   'o3_mean_pred': '30.679686765',
#   'o3_med_pred': '30.78775',
#   'o3_pop_pred': '30.64927408',
#   'statefips': '8',
#   'year': '2012'},
#  {'countyfips': '8014',
#   'date': '01JAN2012',
#   'o3_max_pred': '27.755',
#   'o3_mean_pred': '26.9374',
#   'o3_med_pred': '26.79035',
#   'o3_pop_pred': '26.761529746',
#   'statefips': '8',
#   'year': '2012'},
#  {'countyfips': '8015',
#   'date': '01JAN2012',
#   'o3_max_pred': '36.896',
#   'o3_mean_pred': '35.12108',
#   'o3_med_pred': '34.8787',
#   'o3_pop_pred': '35.241902476',
#   'statefips': '8',
#   'year': '2012'},
#  {'countyfips': '8017',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.0458',
#   'o3_mean_pred': '33.0458',
#   'o3_med_pred': '33.0458',
#   'o3_pop_pred': '33.0458',
#   'statefips': '8',
#   'year': '2012'},
#  {'countyfips': '8019',
#   'date': '01JAN2012',
#   'o3_max_pred': '36.528',
#   'o3_mean_pred': '35.140166667',
#   'o3_med_pred': '34.5713',
#   'o3_pop_pred': '34.977184837',
#   'statefips': '8',
#   'year': '2012'},
#  {'countyfips': '8021',
#   'date': '01JAN2012',
#   'o3_max_pred': '35.5967',
#   'o3_mean_pred': '34.9827',
#   'o3_med_pred': '34.9827',
#   'o3_pop_pred': '35.018546415',
#   'statefips': '8',
#   'year': '2012'},
#  {'countyfips': '8023',
#   'date': '01JAN2012',
#   'o3_max_pred': '34.804',
#   'o3_mean_pred': '34.7297',
#   'o3_med_pred': '34.7297',
#   'o3_pop_pred': '34.734591487',
#   'statefips': '8',
#   'year': '2012'},
#  {'countyfips': '8025',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.0132',
#   'o3_mean_pred': '31.0132',
#   'o3_med_pred': '31.0132',
#   'o3_pop_pred': '31.0132',
#   'statefips': '8',
#   'year': '2012'},
#  {'countyfips': '8027',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.6862',
#   'o3_mean_pred': '32.6862',
#   'o3_med_pred': '32.6862',
#   'o3_pop_pred': '32.6862',
#   'statefips': '8',
#   'year': '2012'},
#  {'countyfips': '8029',
#   'date': '01JAN2012',
#   'o3_max_pred': '37.304',
#   'o3_mean_pred': '36.8182',
#   'o3_med_pred': '36.8676',
#   'o3_pop_pred': '36.856998914',
#   'statefips': '8',
#   'year': '2012'},
#  {'countyfips': '8031',
#   'date': '01JAN2012',
#   'o3_max_pred': '26.9774',
#   'o3_mean_pred': '23.449997222',
#   'o3_med_pred': '23.27275',
# ...
#   'year': '2012'},
#  {'countyfips': '20139',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.089',
#   'o3_mean_pred': '32.89714',
#   'o3_med_pred': '32.8465',
#   'o3_pop_pred': '32.932654759',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20141',
#   'date': '01JAN2012',
#   'o3_max_pred': '28.5168',
#   'o3_mean_pred': '28.5168',
#   'o3_med_pred': '28.5168',
#   'o3_pop_pred': '28.5168',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20143',
#   'date': '01JAN2012',
#   'o3_max_pred': '30.0988',
#   'o3_mean_pred': '29.9124',
#   'o3_med_pred': '29.9124',
#   'o3_pop_pred': '29.858631358',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20145',
#   'date': '01JAN2012',
#   'o3_max_pred': '28.2875',
#   'o3_mean_pred': '28.2044',
#   'o3_med_pred': '28.2044',
#   'o3_pop_pred': '28.160031536',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20147',
#   'date': '01JAN2012',
#   'o3_max_pred': '28.1103',
#   'o3_mean_pred': '28.0226',
#   'o3_med_pred': '27.9854',
#   'o3_pop_pred': '28.00942843',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20149',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.7634',
#   'o3_mean_pred': '32.44705',
#   'o3_med_pred': '32.4029',
#   'o3_pop_pred': '32.424934961',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20151',
#   'date': '01JAN2012',
#   'o3_max_pred': '28.3988',
#   'o3_mean_pred': '28.316866667',
#   'o3_med_pred': '28.293',
#   'o3_pop_pred': '28.303286868',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20153',
#   'date': '01JAN2012',
#   'o3_max_pred': '30.6069',
#   'o3_mean_pred': '30.6069',
#   'o3_med_pred': '30.6069',
#   'o3_pop_pred': '30.6069',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20155',
#   'date': '01JAN2012',
#   'o3_max_pred': '28.1199',
#   'o3_mean_pred': '27.976441176',
#   'o3_med_pred': '27.9907',
#   'o3_pop_pred': '27.966835341',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20157',
#   'date': '01JAN2012',
#   'o3_max_pred': '30.7868',
#   'o3_mean_pred': '30.6555',
#   'o3_med_pred': '30.7157',
#   'o3_pop_pred': '30.662181386',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20159',
#   'date': '01JAN2012',
#   'o3_max_pred': '28.0347',
#   'o3_mean_pred': '27.878266667',
#   'o3_med_pred': '27.9011',
#   'o3_pop_pred': '27.899804671',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20161',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.1694',
#   'o3_mean_pred': '31.954607143',
#   'o3_med_pred': '32.01235',
#   'o3_pop_pred': '31.942898983',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20163',
#   'date': '01JAN2012',
#   'o3_max_pred': '29.1168',
#   'o3_mean_pred': '28.8501',
#   'o3_med_pred': '28.8501',
#   'o3_pop_pred': '28.905643196',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20165',
#   'date': '01JAN2012',
#   'o3_max_pred': '28.5146',
#   'o3_mean_pred': '28.29565',
#   'o3_med_pred': '28.29565',
#   'o3_pop_pred': '28.239969035',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20167',
#   'date': '01JAN2012',
#   'o3_max_pred': '27.6478',
#   'o3_mean_pred': '27.6241',
#   'o3_med_pred': '27.6241',
#   'o3_pop_pred': '27.63215868',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20169',
#   'date': '01JAN2012',
#   'o3_max_pred': '29.5136',
#   'o3_mean_pred': '29.113741667',
#   'o3_med_pred': '29.0911',
#   'o3_pop_pred': '29.13347653',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20171',
#   'date': '01JAN2012',
#   'o3_max_pred': '29.8008',
#   'o3_mean_pred': '29.8008',
#   'o3_med_pred': '29.8008',
#   'o3_pop_pred': '29.8008',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20173',
#   'date': '01JAN2012',
#   'o3_max_pred': '29.3414',
#   'o3_mean_pred': '28.817150806',
#   'o3_med_pred': '28.80735',
#   'o3_pop_pred': '28.819934418',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20175',
#   'date': '01JAN2012',
#   'o3_max_pred': '28.8614',
#   'o3_mean_pred': '28.55042',
#   'o3_med_pred': '28.5712',
#   'o3_pop_pred': '28.599985696',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20177',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.2176',
#   'o3_mean_pred': '32.975465116',
#   'o3_med_pred': '32.9796',
#   'o3_pop_pred': '32.974910232',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20179',
#   'date': '01JAN2012',
#   'o3_max_pred': '30.6049',
#   'o3_mean_pred': '30.59695',
#   'o3_med_pred': '30.59695',
#   'o3_pop_pred': '30.596595423',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20181',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.6491',
#   'o3_mean_pred': '31.4849',
#   'o3_med_pred': '31.4849',
#   'o3_pop_pred': '31.587955308',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20183',
#   'date': '01JAN2012',
#   'o3_max_pred': '28.6917',
#   'o3_mean_pred': '28.62685',
#   'o3_med_pred': '28.62685',
#   'o3_pop_pred': '28.631040929',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20185',
#   'date': '01JAN2012',
#   'o3_max_pred': '27.9519',
#   'o3_mean_pred': '27.95175',
#   'o3_med_pred': '27.95175',
#   'o3_pop_pred': '27.951736038',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20187',
#   'date': '01JAN2012',
#   'o3_max_pred': '30.8728',
#   'o3_mean_pred': '30.8728',
#   'o3_med_pred': '30.8728',
#   'o3_pop_pred': '30.8728',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20189',
#   'date': '01JAN2012',
#   'o3_max_pred': '29.708',
#   'o3_mean_pred': '29.62055',
#   'o3_med_pred': '29.62055',
#   'o3_pop_pred': '29.658683333',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20191',
#   'date': '01JAN2012',
#   'o3_max_pred': '29.6744',
#   'o3_mean_pred': '29.39865',
#   'o3_med_pred': '29.42945',
#   'o3_pop_pred': '29.388077254',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20193',
#   'date': '01JAN2012',
#   'o3_max_pred': '30.5438',
#   'o3_mean_pred': '30.52995',
#   'o3_med_pred': '30.52995',
#   'o3_pop_pred': '30.523049544',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20195',
#   'date': '01JAN2012',
#   'o3_max_pred': '30.1316',
#   'o3_mean_pred': '30.1316',
#   'o3_med_pred': '30.1316',
#   'o3_pop_pred': '30.1316',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20197',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.4788',
#   'o3_mean_pred': '32.3938',
#   'o3_med_pred': '32.3938',
#   'o3_pop_pred': '32.370118588',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20199',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.8384',
#   'o3_mean_pred': '31.8384',
#   'o3_med_pred': '31.8384',
#   'o3_pop_pred': '31.8384',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20201',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.3155',
#   'o3_mean_pred': '31.2192',
#   'o3_med_pred': '31.2192',
#   'o3_pop_pred': '31.23027641',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20203',
#   'date': '01JAN2012',
#   'o3_max_pred': '30.549',
#   'o3_mean_pred': '30.549',
#   'o3_med_pred': '30.549',
#   'o3_pop_pred': '30.549',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20205',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.8276',
#   'o3_mean_pred': '31.7105',
#   'o3_med_pred': '31.7145',
#   'o3_pop_pred': '31.721028632',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20207',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.2072',
#   'o3_mean_pred': '32.14395',
#   'o3_med_pred': '32.14395',
#   'o3_pop_pred': '32.141445996',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '20209',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.429',
#   'o3_mean_pred': '32.894382857',
#   'o3_med_pred': '32.86405',
#   'o3_pop_pred': '32.916636685',
#   'statefips': '20',
#   'year': '2012'},
#  {'countyfips': '21001',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.9695',
#   'o3_mean_pred': '33.772442857',
#   'o3_med_pred': '33.7722',
#   'o3_pop_pred': '33.760578345',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21003',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.5008',
#   'o3_mean_pred': '33.263',
#   'o3_med_pred': '33.2579',
#   'o3_pop_pred': '33.261553628',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21005',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.8507',
#   'o3_mean_pred': '32.65994',
#   'o3_med_pred': '32.6576',
#   'o3_pop_pred': '32.625073797',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21007',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.2972',
#   'o3_mean_pred': '33.2704',
#   'o3_med_pred': '33.2738',
#   'o3_pop_pred': '33.263532574',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21009',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.3492',
#   'o3_mean_pred': '33.17266',
#   'o3_med_pred': '33.16065',
#   'o3_pop_pred': '33.152954025',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21011',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.6073',
#   'o3_mean_pred': '32.437466667',
#   'o3_med_pred': '32.3871',
#   'o3_pop_pred': '32.41872923',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21013',
#   'date': '01JAN2012',
#   'o3_max_pred': '34.0805',
#   'o3_mean_pred': '33.745788889',
#   'o3_med_pred': '33.6481',
#   'o3_pop_pred': '33.767454498',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21015',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.1923',
#   'o3_mean_pred': '30.906004545',
#   'o3_med_pred': '30.927',
#   'o3_pop_pred': '30.916423409',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21017',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.5557',
#   'o3_mean_pred': '32.31275',
#   'o3_med_pred': '32.2592',
#   'o3_pop_pred': '32.293921606',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21019',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.1565',
#   'o3_mean_pred': '31.397246154',
#   'o3_med_pred': '31.2475',
#   'o3_pop_pred': '31.468358774',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21021',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.7047',
#   'o3_mean_pred': '33.468885714',
#   'o3_med_pred': '33.3888',
#   'o3_pop_pred': '33.457047418',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21023',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.5259',
#   'o3_mean_pred': '31.488066667',
#   'o3_med_pred': '31.4859',
#   'o3_pop_pred': '31.494850224',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21025',
#   'date': '01JAN2012',
#   'o3_max_pred': '35.1046',
#   'o3_mean_pred': '34.717971429',
#   'o3_med_pred': '34.6915',
#   'o3_pop_pred': '34.71436898',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21027',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.2608',
#   'o3_mean_pred': '33.19255',
#   'o3_med_pred': '33.19355',
#   'o3_pop_pred': '33.174319243',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21029',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.5393',
#   'o3_mean_pred': '32.019794444',
#   'o3_med_pred': '31.9808',
#   'o3_pop_pred': '31.980709097',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21031',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.8283',
#   'o3_mean_pred': '33.70464',
#   'o3_med_pred': '33.712',
#   'o3_pop_pred': '33.73497985',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21033',
#   'date': '01JAN2012',
#   'o3_max_pred': '34.2058',
#   'o3_mean_pred': '34.118733333',
#   'o3_med_pred': '34.1202',
#   'o3_pop_pred': '34.097579082',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21035',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.8703',
#   'o3_mean_pred': '33.750077778',
#   'o3_med_pred': '33.769',
#   'o3_pop_pred': '33.753406526',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21037',
#   'date': '01JAN2012',
#   'o3_max_pred': '30.776',
#   'o3_mean_pred': '30.177208',
#   'o3_med_pred': '30.1063',
#   'o3_pop_pred': '30.215769737',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21039',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.6402',
#   'o3_mean_pred': '33.4629',
#   'o3_med_pred': '33.4603',
#   'o3_pop_pred': '33.454145357',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21041',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.0567',
#   'o3_mean_pred': '31.921433333',
#   'o3_med_pred': '31.9462',
#   'o3_pop_pred': '31.863045343',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21043',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.6779',
#   'o3_mean_pred': '32.382',
#   'o3_med_pred': '32.3432',
#   'o3_pop_pred': '32.396439275',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21045',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.9737',
#   'o3_mean_pred': '33.77228',
#   'o3_med_pred': '33.7698',
#   'o3_pop_pred': '33.743643297',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21047',
#   'date': '01JAN2012',
#   'o3_max_pred': '34.2068',
#   'o3_mean_pred': '33.956773684',
#   'o3_med_pred': '33.9937',
#   'o3_pop_pred': '33.932272052',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21049',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.6277',
#   'o3_mean_pred': '32.44921',
#   'o3_med_pred': '32.44845',
#   'o3_pop_pred': '32.444809213',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21051',
#   'date': '01JAN2012',
#   'o3_max_pred': '34.7904',
#   'o3_mean_pred': '34.49415',
#   'o3_med_pred': '34.50915',
#   'o3_pop_pred': '34.478402927',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21053',
#   'date': '01JAN2012',
#   'o3_max_pred': '34.3663',
#   'o3_mean_pred': '34.227666667',
#   'o3_med_pred': '34.1845',
#   'o3_pop_pred': '34.224703174',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21055',
#   'date': '01JAN2012',
#   'o3_max_pred': '34.031',
#   'o3_mean_pred': '33.86615',
#   'o3_med_pred': '33.88365',
#   'o3_pop_pred': '33.912764294',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21057',
#   'date': '01JAN2012',
#   'o3_max_pred': '34.189',
#   'o3_mean_pred': '33.9968',
#   'o3_med_pred': '33.9968',
#   'o3_pop_pred': '33.955141715',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21059',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.4827',
#   'o3_mean_pred': '33.066043478',
#   'o3_med_pred': '33.0334',
#   'o3_pop_pred': '33.087177002',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21061',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.7149',
#   'o3_mean_pred': '33.631925',
#   'o3_med_pred': '33.65985',
#   'o3_pop_pred': '33.575221404',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21063',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.212',
#   'o3_mean_pred': '33.1107',
#   'o3_med_pred': '33.1107',
#   'o3_pop_pred': '33.065236271',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21065',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.3573',
#   'o3_mean_pred': '33.258325',
#   'o3_med_pred': '33.28355',
#   'o3_pop_pred': '33.238272785',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21067',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.7749',
#   'o3_mean_pred': '32.478636585',
#   'o3_med_pred': '32.47675',
#   'o3_pop_pred': '32.4885197',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21069',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.2847',
#   'o3_mean_pred': '31.960975',
#   'o3_med_pred': '31.8932',
#   'o3_pop_pred': '31.975082304',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21071',
#   'date': '01JAN2012',
#   'o3_max_pred': '36.07',
#   'o3_mean_pred': '35.34393',
#   'o3_med_pred': '35.29045',
#   'o3_pop_pred': '35.329431895',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21073',
#   'date': '01JAN2012',
#   'o3_max_pred': '32.6857',
#   'o3_mean_pred': '32.5485',
#   'o3_med_pred': '32.585',
#   'o3_pop_pred': '32.547213594',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21075',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.1208',
#   'o3_mean_pred': '32.99605',
#   'o3_med_pred': '32.99605',
#   'o3_pop_pred': '33.010533671',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21077',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.6864',
#   'o3_mean_pred': '31.574',
#   'o3_med_pred': '31.574',
#   'o3_pop_pred': '31.623244522',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21079',
#   'date': '01JAN2012',
#   'o3_max_pred': '33.3339',
#   'o3_mean_pred': '33.150775',
#   'o3_med_pred': '33.1184',
#   'o3_pop_pred': '33.128590143',
#   'statefips': '21',
#   'year': '2012'},
#  {'countyfips': '21081',
#   'date': '01JAN2012',
#   'o3_max_pred': '31.9896',
#   'o3_mean_pred': '31.6807',
#   'o3_med_pred': '31.6097',
#   'o3_pop_pred': '31.611564484',
#   'statefips': '21',
#   'year': '2012'}]

# %%
data_table2012 = pd.DataFrame(data)
data_table2012

new_data_table2012 = data_table2012[["countyfips", "o3_max_pred","o3_mean_pred", "o3_med_pred", "o3_pop_pred", "statefips", "year"]]
new_data_table2012

new_data_table2012 = new_data_table2012.dropna(how='any')

ozone_data_abbreviated2012 = new_data_table2012[(new_data_table2012["statefips"] == '6')]
ozone_data_abbreviated2012

ozone_data_abbreviated2012 = ozone_data_abbreviated2012.apply(pd.to_numeric)

ozone_data_abbreviated2012.dtypes
# Out:
# countyfips        int64
# o3_max_pred     float64
# o3_mean_pred    float64
# o3_med_pred     float64
# o3_pop_pred     float64
# statefips         int64
# year              int64
# dtype: object

# %%
url2009= " https://data.cdc.gov/resource/hiea-rbwm.json?year=2009"
response2009= requests.get(url2009)
print(response2009.url)

data2009 = response2009.json()
# Out:
# https://data.cdc.gov/resource/hiea-rbwm.json?year=2009

# %%
data_table2009 = pd.DataFrame(data2009)
data_table2009

new_data_table2009 = data_table2009[["countyfips", "o3_max_pred","o3_mean_pred", "o3_med_pred", "o3_pop_pred", "statefips", "year"]]
new_data_table2009

new_data_table2009 = new_data_table2009.dropna(how='any')

ozone_data_abbreviated2009 = new_data_table2009[(new_data_table2009["statefips"] == '6')]
ozone_data_abbreviated2009

ozone_data_abbreviated2009 = ozone_data_abbreviated2009.apply(pd.to_numeric)

ozone_data_abbreviated2009.dtypes
# Out:
# countyfips        int64
# o3_max_pred     float64
# o3_mean_pred    float64
# o3_med_pred     float64
# o3_pop_pred     float64
# statefips         int64
# year              int64
# dtype: object

# %%
ozone_combined = pd.concat([ozone_data_abbreviated2009, ozone_data_abbreviated2012],ignore_index=True)
ozone_combined
# Out:
#      countyfips  o3_max_pred  o3_mean_pred  o3_med_pred  o3_pop_pred  \
# 0          6001    17.264643     11.740056    11.303074    11.927295
# 1          6003    32.169198     32.169198    32.169198    32.169198
# 2          6005    26.488681     17.971428    17.522647    17.284726
# 3          6007    21.482822     13.901565    12.604104    13.863149
# 4          6009    25.516332     18.798751    18.472967    17.376064
# ..          ...          ...           ...          ...          ...
# 111        6107    39.984500     35.539917    35.415450    35.548904
# 112        6109    35.423300     29.584527    29.314600    29.858629
# 113        6111    39.708400     34.894140    34.977400    34.847260
# 114        6113    22.632100     20.006563    20.382900    19.990952
# 115        6115    28.816200     21.162400    20.084200    21.008260
#
#      statefips  year
# 0            6  2009
# 1            6  2009
# 2            6  2009
# 3            6  2009
# 4            6  2009
# ..         ...   ...
# 111          6  2012
# 112          6  2012
# 113          6  2012
# 114          6  2012
# 115          6  2012
#
# [116 rows x 7 columns]

# %%
ozone_combined.describe()
# Out:
#         countyfips  o3_max_pred  o3_mean_pred  o3_med_pred  o3_pop_pred  \
# count   116.000000   116.000000    116.000000   116.000000   116.000000
# mean   6058.000000    28.105167     23.346957    23.020403    23.238493
# std      33.626594     7.350134      7.224815     7.517229     7.253396
# min    6001.000000    13.146376     10.845693    10.396075    10.764609
# 25%    6029.000000    22.731400     17.867903    17.383176    17.498561
# 50%    6058.000000    28.448400     22.880890    22.693750    22.838333
# 75%    6087.000000    32.787027     29.344216    29.331512    29.075287
# max    6115.000000    42.074000     37.929250    38.933000    37.887841
#
#        statefips         year
# count      116.0   116.000000
# mean         6.0  2010.500000
# std          0.0     1.506508
# min          6.0  2009.000000
# 25%          6.0  2009.000000
# 50%          6.0  2010.500000
# 75%          6.0  2012.000000
# max          6.0  2012.000000

# %%
#open cdc data csv
cdc_csv = "../MVP-Solutions/Air_Quality_Measures_on_the_National_Environmental_Health_Tracking_Network.csv"

cdc_data= pd.read_csv(cdc_csv)

cdc_df = pd.DataFrame(cdc_data)

cdc_df


#cdc_df["ReportYear"].unique()

#cdc_group_year = cdc_df.groupby()
# Out:
#         MeasureId                                        MeasureName  \
# 0              83  Number of days with maximum 8-hour average ozo...
# 1              83  Number of days with maximum 8-hour average ozo...
# 2              83  Number of days with maximum 8-hour average ozo...
# 3              83  Number of days with maximum 8-hour average ozo...
# 4              83  Number of days with maximum 8-hour average ozo...
# ...           ...                                                ...
# 218630        296  Annual average ambient concentrations of PM 2....
# 218631        296  Annual average ambient concentrations of PM 2....
# 218632        296  Annual average ambient concentrations of PM 2....
# 218633        296  Annual average ambient concentrations of PM 2....
# 218634        296  Annual average ambient concentrations of PM 2....
#
#        MeasureType StratificationLevel  StateFips    StateName  CountyFips  \
# 0           Counts      State x County          1      Alabama        1027
# 1           Counts      State x County          1      Alabama        1051
# 2           Counts      State x County          1      Alabama        1073
# 3           Counts      State x County          1      Alabama        1079
# 4           Counts      State x County          1      Alabama        1089
# ...            ...                 ...        ...          ...         ...
# 218630     Average      State x County          9  Connecticut        9015
# 218631     Average      State x County          9  Connecticut        9015
# 218632     Average      State x County          9  Connecticut        9015
# 218633     Average      State x County          9  Connecticut        9015
# 218634     Average      State x County          9  Connecticut        9015
#
#        CountyName  ReportYear      Value      Unit                   UnitName  \
# 0            Clay        1999  33.000000  No Units                   No Units
# 1          Elmore        1999   5.000000  No Units                   No Units
# 2       Jefferson        1999  39.000000  No Units                   No Units
# 3        Lawrence        1999  28.000000  No Units                   No Units
# 4         Madison        1999  31.000000  No Units                   No Units
# ...           ...         ...        ...       ...                        ...
# 218630    Windham        2007  10.793911     µg/m³  Micograms per cubic meter
# 218631    Windham        2008  10.081848     µg/m³  Micograms per cubic meter
# 218632    Windham        2009   8.733175     µg/m³  Micograms per cubic meter
# 218633    Windham        2010   8.082464     µg/m³  Micograms per cubic meter
# 218634    Windham        2011   8.916821     µg/m³  Micograms per cubic meter
#
#                DataOrigin  MonitorOnly
# 0            Monitor Only            1
# 1            Monitor Only            1
# 2            Monitor Only            1
# 3            Monitor Only            1
# 4            Monitor Only            1
# ...                   ...          ...
# 218630  Monitor & Modeled            0
# 218631  Monitor & Modeled            0
# 218632  Monitor & Modeled            0
# 218633  Monitor & Modeled            0
# 218634  Monitor & Modeled            0
#
# [218635 rows x 14 columns]

# %%
#cdc data for columns of interest
column_names = cdc_df.columns
print(column_names)
print(cdc_df.dtypes)

new_cdc_df = cdc_df[['MeasureId', 'MeasureName','StateFips', 'StateName', 'CountyFips', 'CountyName', 'ReportYear',
       'Value']]
new_cdc_df
# Out:
# Index(['MeasureId', 'MeasureName', 'MeasureType', 'StratificationLevel',
#        'StateFips', 'StateName', 'CountyFips', 'CountyName', 'ReportYear',
#        'Value', 'Unit', 'UnitName', 'DataOrigin', 'MonitorOnly'],
#       dtype='object')
# MeasureId                int64
# MeasureName             object
# MeasureType             object
# StratificationLevel     object
# StateFips                int64
# StateName               object
# CountyFips               int64
# CountyName              object
# ReportYear               int64
# Value                  float64
# Unit                    object
# UnitName                object
# DataOrigin              object
# MonitorOnly              int64
# dtype: object
#         MeasureId                                        MeasureName  \
# 0              83  Number of days with maximum 8-hour average ozo...
# 1              83  Number of days with maximum 8-hour average ozo...
# 2              83  Number of days with maximum 8-hour average ozo...
# 3              83  Number of days with maximum 8-hour average ozo...
# 4              83  Number of days with maximum 8-hour average ozo...
# ...           ...                                                ...
# 218630        296  Annual average ambient concentrations of PM 2....
# 218631        296  Annual average ambient concentrations of PM 2....
# 218632        296  Annual average ambient concentrations of PM 2....
# 218633        296  Annual average ambient concentrations of PM 2....
# 218634        296  Annual average ambient concentrations of PM 2....
#
#         StateFips    StateName  CountyFips CountyName  ReportYear      Value
# 0               1      Alabama        1027       Clay        1999  33.000000
# 1               1      Alabama        1051     Elmore        1999   5.000000
# 2               1      Alabama        1073  Jefferson        1999  39.000000
# 3               1      Alabama        1079   Lawrence        1999  28.000000
# 4               1      Alabama        1089    Madison        1999  31.000000
# ...           ...          ...         ...        ...         ...        ...
# 218630          9  Connecticut        9015    Windham        2007  10.793911
# 218631          9  Connecticut        9015    Windham        2008  10.081848
# 218632          9  Connecticut        9015    Windham        2009   8.733175
# 218633          9  Connecticut        9015    Windham        2010   8.082464
# 218634          9  Connecticut        9015    Windham        2011   8.916821
#
# [218635 rows x 8 columns]

# %%
#cdc data without na's
new_cdc_df = new_cdc_df.dropna(how='any')
new_cdc_df.count()
# Out:
# MeasureId      218635
# MeasureName    218635
# StateFips      218635
# StateName      218635
# CountyFips     218635
# CountyName     218635
# ReportYear     218635
# Value          218635
# dtype: int64

# %%
#cdc data for california 
cdc_df_abbreviated = new_cdc_df[(new_cdc_df["StateName"] == 'California')]
print(cdc_df_abbreviated["ReportYear"].unique())
cdc_df_abbreviated.sort_values("ReportYear", ascending=False)
# Out:
# [1999 2010 2009 2000 2001 2002 2003 2004 2005 2006 2007 2008 2011 2012
#  2013]
#         MeasureId                                        MeasureName  \
# 208412         84  Number of person-days with maximum 8-hour aver...
# 208572         85  Percent of days with PM2.5 levels over the Nat...
# 208452         84  Number of person-days with maximum 8-hour aver...
# 208451         84  Number of person-days with maximum 8-hour aver...
# 208450         84  Number of person-days with maximum 8-hour aver...
# ...           ...                                                ...
# 209412         86  Person-days with PM2.5 over the National Ambie...
# 209424         86  Person-days with PM2.5 over the National Ambie...
# 209429         86  Person-days with PM2.5 over the National Ambie...
# 207060         83  Number of days with maximum 8-hour average ozo...
# 207027         83  Number of days with maximum 8-hour average ozo...
#
#         StateFips   StateName  CountyFips     CountyName  ReportYear  \
# 208412          6  California        6001        Alameda        2013
# 208572          6  California        6061         Placer        2013
# 208452          6  California        6097         Sonoma        2013
# 208451          6  California        6095         Solano        2013
# 208450          6  California        6093       Siskiyou        2013
# ...           ...         ...         ...            ...         ...
# 209412          6  California        6057         Nevada        1999
# 209424          6  California        6083  Santa Barbara        1999
# 209429          6  California        6075  San Francisco        1999
# 207060          6  California        6083  Santa Barbara        1999
# 207027          6  California        6001        Alameda        1999
#
#              Value
# 208412   1578891.0
# 208572         0.0
# 208452         0.0
# 208451         0.0
# 208450         0.0
# ...            ...
# 209412    419976.0
# 209424         0.0
# 209429  32627462.0
# 207060        12.0
# 207027        15.0
#
# [6293 rows x 8 columns]

# %%
#california for only 2009,2012
cdc_df_abbreviated = new_cdc_df[(new_cdc_df["StateName"] == 'California')]
cdc_df_abbreviated.sort_values("ReportYear", ascending=False)

cdc_df_abbreviated_2012 = cdc_df_abbreviated[(cdc_df_abbreviated["ReportYear"] == 2012)]
cdc_df_abbreviated_2012.sort_values("MeasureId", ascending=True)

cdc_df_abbreviated_2009 = cdc_df_abbreviated[(cdc_df_abbreviated["ReportYear"] == 2009)]
cdc_df_abbreviated_2009.sort_values("MeasureId", ascending=True)

#california for measure id 83, 87, 292, 296

cdc_df_abbreviated_2012_PM = cdc_df_abbreviated_2012[(cdc_df_abbreviated_2012["MeasureId"] == 83) | 
                                                     (cdc_df_abbreviated_2012["MeasureId"] == 87) | 
                                                     (cdc_df_abbreviated_2012["MeasureId"] == 292) | 
                                                     (cdc_df_abbreviated_2012["MeasureId"] == 296) 
                                                    ]

cdc_df_abbreviated_2009_PM = cdc_df_abbreviated_2009[(cdc_df_abbreviated_2009["MeasureId"] == 83) | 
                                                     (cdc_df_abbreviated_2009["MeasureId"] == 87) | 
                                                     (cdc_df_abbreviated_2009["MeasureId"] == 292) | 
                                                     (cdc_df_abbreviated_2009["MeasureId"] == 296) 
                                                    ]

cdc_df_abbreviated_2009_PM
# Out:
#         MeasureId                                        MeasureName  \
# 207970         83  Number of days with maximum 8-hour average ozo...
# 207971         83  Number of days with maximum 8-hour average ozo...
# 207972         83  Number of days with maximum 8-hour average ozo...
# 207973         83  Number of days with maximum 8-hour average ozo...
# 207974         83  Number of days with maximum 8-hour average ozo...
# ...           ...                                                ...
# 213273        296  Annual average ambient concentrations of PM 2....
# 213284        296  Annual average ambient concentrations of PM 2....
# 213295        296  Annual average ambient concentrations of PM 2....
# 213306        296  Annual average ambient concentrations of PM 2....
# 213317        296  Annual average ambient concentrations of PM 2....
#
#         StateFips   StateName  CountyFips CountyName  ReportYear      Value
# 207970          6  California        6001    Alameda        2009   6.000000
# 207971          6  California        6005     Amador        2009   1.000000
# 207972          6  California        6007      Butte        2009  13.000000
# 207973          6  California        6009  Calaveras        2009   9.000000
# 207974          6  California        6011     Colusa        2009   0.000000
# ...           ...         ...         ...        ...         ...        ...
# 213273          6  California        6107     Tulare        2009  16.132244
# 213284          6  California        6109   Tuolumne        2009   9.679406
# 213295          6  California        6111    Ventura        2009  12.650455
# 213306          6  California        6113       Yolo        2009  10.021694
# 213317          6  California        6115       Yuba        2009   9.183091
#
# [201 rows x 8 columns]

# %%
#df 2012 with correct dtypes
final_cdc_df_2012 = cdc_df_abbreviated_2012_PM[['MeasureId','StateFips', 'CountyFips', 'ReportYear','Value']]
final_cdc_df_2012 = final_cdc_df_2012.apply(pd.to_numeric)


final_cdc_df_2012 = final_cdc_df_2012.rename(columns={'CountyFips': 'countyfips', 'ReportYear': 'year'})

final_cdc_df_2012
# Out:
#         MeasureId  StateFips  countyfips  year      Value
# 208267         83          6        6001  2012   3.000000
# 208268         83          6        6005  2012   7.000000
# 208269         83          6        6007  2012   5.000000
# 208270         83          6        6009  2012   4.000000
# 208271         83          6        6011  2012   0.000000
# ...           ...        ...         ...   ...        ...
# 210097         87          6        6025  2012  14.730109
# 210106         87          6        6073  2012  11.070058
# 210114         87          6        6063  2012  13.045682
# 210120         87          6        6057  2012   6.220911
# 210126         87          6        6113  2012   6.445686
#
# [74 rows x 5 columns]

# %%
final_cdc_df_2009 = cdc_df_abbreviated_2009_PM[['MeasureId','StateFips', 'CountyFips', 'ReportYear','Value']]
final_cdc_df_2009 = final_cdc_df_2009.apply(pd.to_numeric)


final_cdc_df_2009 = final_cdc_df_2009.rename(columns={'CountyFips': 'countyfips', 'ReportYear': 'year'})

final_cdc_df_2009
# Out:
#         MeasureId  StateFips  countyfips  year      Value
# 207970         83          6        6001  2009   6.000000
# 207971         83          6        6005  2009   1.000000
# 207972         83          6        6007  2009  13.000000
# 207973         83          6        6009  2009   9.000000
# 207974         83          6        6011  2009   0.000000
# ...           ...        ...         ...   ...        ...
# 213273        296          6        6107  2009  16.132244
# 213284        296          6        6109  2009   9.679406
# 213295        296          6        6111  2009  12.650455
# 213306        296          6        6113  2009  10.021694
# 213317        296          6        6115  2009   9.183091
#
# [201 rows x 5 columns]

# %%
#cdc_df_2012_2009_combined = pd.concat([cdc_df_abbreviated_2012_PM, cdc_df_abbreviated_2009_PM],ignore_index=True) 
#cdc_df_2012_2009_combined

# %%
#open CA Asthma CSV
ca_csv = "../MVP-Solutions/Asthma_Emergency_Department_Visit_Rates_by_ZIP_Code.csv"

ca_asthma_data= pd.read_csv(ca_csv)
ca_asthma_data_clean = ca_asthma_data
ca_asthma_data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-28-44fc6a90a97f> in <module>
#       2 ca_csv = "../MVP-Solutions/Asthma_Emergency_Department_Visit_Rates_by_ZIP_Code.csv"
#       3
# ----> 4 ca_asthma_data= pd.read_csv(ca_csv)
#       5 ca_asthma_data_clean = ca_asthma_data
#       6 ca_asthma_data
#
# ~\Anaconda\Anaconda\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~\Anaconda\Anaconda\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~\Anaconda\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda\Anaconda\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~\Anaconda\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1904         kwds["usecols"] = self.usecols
#    1905
# -> 1906         self._reader = parsers.TextReader(src, **kwds)
#    1907         self.unnamed_cols = self._reader.unnamed_cols
#    1908
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'../MVP-Solutions/Asthma_Emergency_Department_Visit_Rates_by_ZIP_Code.csv' does not exist: b'../MVP-Solutions/Asthma_Emergency_Department_Visit_Rates_by_ZIP_Code.csv'

# %%
ca_asthma_data= ca_asthma_data.rename(columns={'County Fips code': 'countyfips', 'ZIP code': 'zip', 'Age Group': 'Age_Group', 
                                               'Number of Visits':"NumVisits", "Age-adjusted rate": "Age_adjusted_rate"})
ca_asthma_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-1f06de37bf26> in <module>
# ----> 1 ca_asthma_data= ca_asthma_data.rename(columns={'County Fips code': 'countyfips', 'ZIP code': 'zip', 'Age Group': 'Age_Group',
#       2                                                'Number of Visits':"NumVisits", "Age-adjusted rate": "Age_adjusted_rate"})
#       3 ca_asthma_data
#
# NameError: name 'ca_asthma_data' is not defined

# %%
ca_asthma_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-0afaa1a5b8c3> in <module>
# ----> 1 ca_asthma_data
#
# NameError: name 'ca_asthma_data' is not defined

# %%
ca_asthma_data[['Zip_Code', 'Coord']] = ca_asthma_data.zip.apply(lambda x: pd.Series(str(x).split('\n')))
ca_asthma_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-4b2897e57393> in <module>
# ----> 1 ca_asthma_data[['Zip_Code', 'Coord']] = ca_asthma_data.zip.apply(lambda x: pd.Series(str(x).split('\n')))
#       2 ca_asthma_data
#
# NameError: name 'ca_asthma_data' is not defined

# %%
ca_asthma_data[['Lat', 'Lng']] = ca_asthma_data.Coord.apply(lambda x: pd.Series(str(x).split(',')))
ca_asthma_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-6c56603fce87> in <module>
# ----> 1 ca_asthma_data[['Lat', 'Lng']] = ca_asthma_data.Coord.apply(lambda x: pd.Series(str(x).split(',')))
#       2 ca_asthma_data
#
# NameError: name 'ca_asthma_data' is not defined

# %%
ca_asthma_data["Lat"] = ca_asthma_data["Lat"].str.replace('(', '')
ca_asthma_data["Lng"] = ca_asthma_data["Lng"].str.replace(')', '')
ca_asthma_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-2b715375fab6> in <module>
# ----> 1 ca_asthma_data["Lat"] = ca_asthma_data["Lat"].str.replace('(', '')
#       2 ca_asthma_data["Lng"] = ca_asthma_data["Lng"].str.replace(')', '')
#       3 ca_asthma_data
#
# NameError: name 'ca_asthma_data' is not defined

# %%
ca_asthma_data.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-6867a221a913> in <module>
# ----> 1 ca_asthma_data.columns
#
# NameError: name 'ca_asthma_data' is not defined

# %%
ca_asthma_data.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-711f2aa71711> in <module>
# ----> 1 ca_asthma_data.dtypes
#
# NameError: name 'ca_asthma_data' is not defined

# %%
ca_asthma_data.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-a3d0d6bd648c> in <module>
# ----> 1 ca_asthma_data.count()
#
# NameError: name 'ca_asthma_data' is not defined

# %%
ca_asthma_data["County"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-8d1f70a06c4d> in <module>
# ----> 1 ca_asthma_data["County"].value_counts()
#
# NameError: name 'ca_asthma_data' is not defined

# %%
ca_asthma_data["County"] = ca_asthma_data["County"].str.replace('CONTRA C;OSTA', 'CONTRA COSTA')
ca_asthma_data["County"] = ca_asthma_data["County"].str.replace('SAN BERNADINO', 'SAN BERNARDINO')
ca_asthma_data["County"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-376ee0cf5834> in <module>
# ----> 1 ca_asthma_data["County"] = ca_asthma_data["County"].str.replace('CONTRA C;OSTA', 'CONTRA COSTA')
#       2 ca_asthma_data["County"] = ca_asthma_data["County"].str.replace('SAN BERNADINO', 'SAN BERNARDINO')
#       3 ca_asthma_data["County"].value_counts()
#
# NameError: name 'ca_asthma_data' is not defined

# %%
ca_asthma_data_clean = ca_asthma_data[['Year', 'Age_Group', 'NumVisits', 'Age_adjusted_rate', 
                                      'countyfips', 'County', 'zip', 'Lat','Lng']]
ca_asthma_data_clean

# %%
# Drop all NA values to clean the data
ca_asthma_data_final = ca_asthma_data_clean.dropna()
ca_asthma_data_final.count()

# %%
ca_asthma_data_final.describe()

# %%
ca_asthma_data_final['Lat'].value_counts().count()

# %%
export_csv=ca_asthma_data_final.to_csv ('export_markasthma_df.csv',index=None,header=True)

# %%
#ca_asthma_data_final_allages = ca_asthma_data_final[ca_asthma_data_final['Age_Group']== 'AllAges']
#ca_asthma_data_final_allages


ca_asthma_data_final_allages = ca_asthma_data_final[(ca_asthma_data_final["Age_Group"] == "AllAges") | 
                                                    (ca_asthma_data_final["Age_Group"] == "All Ages")
                                                    ]
ca_asthma_data_final_allages

# %%
ca_asthma_data_final_allages_gbfips = ca_asthma_data_final_allages.groupby(['countyfips'])
ca_asthma_data_final_allages_gbfips.head()

# %%
ca_asthma_data_final_2009allages = ca_asthma_data_final.loc[ca_asthma_data_final['Age_Group']=='All Ages', :]
ca_asthma_data_final_2009allages

numvisits_byfips_2009 = (ca_asthma_data_final_2009allages.groupby(['countyfips', 'NumVisits'], as_index=False).mean()
           .groupby('countyfips')['NumVisits'].sum())
print(numvisits_byfips_2009)

# %%
numvisits_bycounty_2009 = (ca_asthma_data_final_2009allages.groupby(['County', 'NumVisits'], as_index=False).mean()
           .groupby('County')['NumVisits'].sum())
print(numvisits_bycounty_2009)

# %%
numvisits_bycounty_2009_df = pd.DataFrame(numvisits_bycounty_2009)
numvisits_bycounty_2009_df.head()

# %%
ca_asthma_data_final_2012allages = ca_asthma_data_final.loc[ca_asthma_data_final['Age_Group']=='AllAges', :]
ca_asthma_data_final_2012allages

numvisits_byfips_2012 = (ca_asthma_data_final_2012allages.groupby(['countyfips', 'NumVisits'], as_index=False).mean()
           .groupby('countyfips')['NumVisits'].sum())
print(numvisits_byfips_2012)

# %%
numvisits_bycounty_2012 = (ca_asthma_data_final_2012allages.groupby(['County', 'NumVisits'], as_index=False).mean()
           .groupby('County')['NumVisits'].sum())
countyfips_nums = numvisits_bycounty_2012.index
print(numvisits_bycounty_2012)

# %%
numvisits_bycounty_2012_df = pd.DataFrame(numvisits_bycounty_2012)
numvisits_bycounty_2012_df.head()

# %%
merged_numvisits_bycounty_2009_2012 = pd.merge(numvisits_bycounty_2009_df, numvisits_bycounty_2012_df, on='County')
merged_numvisits_bycounty_2009_2012 = merged_numvisits_bycounty_2009_2012.rename(columns={'NumVisits_x':'2009_Visits', 'NumVisits_y':'2012_Visits'})
#merged_numvisits_bycounty_2009_2012['Countyfips'] = merged_numvisits_bycounty_2009_2012['Countyfips'].append(countyfips_nums)
merged_numvisits_bycounty_2009_2012

# %%
multi_plot = merged_numvisits_bycounty_2009_2012.plot(kind='bar', figsize=(15,10), width=1)
plt.title("2012 California Asthma Hospitalizations by County")
plt.xlabel("County Name")
plt.ylabel("Emergency Department Visits due to Asthma")

# %%
#Calculate % Change in Asthma-related Hospital Visits from 2009 to 2012
pc_change = (merged_numvisits_bycounty_2009_2012['2012_Visits'] - merged_numvisits_bycounty_2009_2012['2009_Visits'])*100 / merged_numvisits_bycounty_2009_2012['2009_Visits']
pc_change

# %%
#Append %Change to DataFrame
merged_numvisits_bycounty_2009_2012['%_Change'] = pc_change
merged_numvisits_bycounty_2009_2012

# %%
#highlight table for percent change 
import seaborn as sns

# Set colormap equal to seaborns light green color palette
cm = sns.light_palette("green", as_cmap=True)

(merged_numvisits_bycounty_2009_2012.style
  .background_gradient(cmap=cm, subset=['%_Change'])
  .highlight_max(subset=['%_Change'])
  .set_caption('Percent Change of 2009 and 2012 Hospital Visits in California Counties')
  .format({'%_Change': "{:.2%}"}))

# %%
#Top 10 largest %Decrease in Asthma-related Hospital Visits from 2009 to 2012
merged_numvisits_bycounty_2009_2012_sorted_asc = merged_numvisits_bycounty_2009_2012.sort_values(by=['%_Change'], ascending=False)
merged_numvisits_bycounty_2009_2012_sorted_asc.head(10)

# %%
#Top 10 largest %Increase in Asthma-related Hospital Visits from 2009 to 2012
merged_numvisits_bycounty_2009_2012_sorted_desc = merged_numvisits_bycounty_2009_2012.sort_values(by=['%_Change'], ascending=True)
merged_numvisits_bycounty_2009_2012_sorted_desc.head(10)

# %%
# Show Heatmap of 2009 Hospitalizations due to Asthma using GoogleMaps API
# The original data set had all the Latitudes and Longitudes before Grouping By County
# Also, I had to convert the Latitutes and Longitudes from Object Type to Float Type for it to work
locations = ca_asthma_data_final_2009allages[['Lat', 'Lng']]
weights = ca_asthma_data_final_2009allages['NumVisits']
fig1 = gmaps.figure()
fig1.add_layer(gmaps.heatmap_layer(locations, weights=weights))
fig1

# %%
# Show Heatmap of 2012 Hospitalizations due to Asthma using GoogleMaps API.  (Not much difference)
# The original data set had all the Latitudes and Longitudes before Grouping By County
# I had to convert the Latitutes and Longitudes from Object Type to Float Type for it to work
locations = ca_asthma_data_final_2012allages[['Lat', 'Lng']]
weights = ca_asthma_data_final_2012allages['NumVisits']
fig2 = gmaps.figure()
fig2.add_layer(gmaps.heatmap_layer(locations, weights=weights))
fig2

# %%
AllAges_2009_2012_ZipCodes = pd.merge(ca_asthma_data_final_2009allages, ca_asthma_data_final_2012allages, on='Zip_Code')
AllAges_2009_2012_ZipCodes

# %%
AllAges_2009_2012_ZipCodes['Difference'] = AllAges_2009_2012_ZipCodes['NumVisits_y']-AllAges_2009_2012_ZipCodes['NumVisits_x']
AllAges_2009_2012_ZipCodes

# %%
# Show Heatmap of 2009 to 2012 differences (Normalized) in Hospitalizations due to Asthma using GoogleMaps API
# I had to Normalize the weights, because Google Maps wouldn't let me use a negative number for the weights
# So I had to add the absolute value of the minimum number (-212.0) to every data point and divide by the spread between Max and Min
# See the instructions: https://datascience.stackexchange.com/questions/5885/how-to-scale-an-array-of-signed-integers-to-range-from-0-to-1
difference = AllAges_2009_2012_ZipCodes['Difference']
min = AllAges_2009_2012_ZipCodes['Difference'].min()
max = AllAges_2009_2012_ZipCodes['Difference'].max()
print(min, max)

# %%
spread = AllAges_2009_2012_ZipCodes['Difference'].max() - AllAges_2009_2012_ZipCodes['Difference'].min()
spread

# %%
AllAges_2009_2012_ZipCodes['Normalized'] = (AllAges_2009_2012_ZipCodes['Difference']+abs(AllAges_2009_2012_ZipCodes['Difference'].min()))/spread
AllAges_2009_2012_ZipCodes

# %%
# Heatmap shows the difference between 2009 to 2012.  Not sure exactly how to read this map
# Had to use the locations from 2012 data set only.
locations = AllAges_2009_2012_ZipCodes[['Lat_y', 'Lng_y']]
weights = AllAges_2009_2012_ZipCodes['Normalized']
fig3 = gmaps.figure()
fig3.add_layer(gmaps.heatmap_layer(locations, weights=weights))
fig3

# %%
#merged num visits asthma 2012 and ozone 2012
numvisits_byfips_2012_df = pd.DataFrame(numvisits_byfips_2012)
numvisits_byfips_2012_df


combined_ozone_asthma_2012 = pd.merge(ozone_data_abbreviated2012, numvisits_byfips_2012_df, how='outer', on='countyfips')
combined_ozone_asthma_2012

# %%
#merged num visits asthma 2009 and ozone 2009 
numvisits_byfips_2009_df = pd.DataFrame(numvisits_byfips_2009)
numvisits_byfips_2009_df


combined_ozone_asthma_2009 = pd.merge(ozone_data_abbreviated2009, numvisits_byfips_2009_df, how='outer', on='countyfips')
combined_ozone_asthma_2009

# %%
#merged num visits asthma 2012 and cdc 2012
combined_cdc_asthma_2012 = pd.merge(final_cdc_df_2012, numvisits_byfips_2012_df, on="countyfips")

combined_cdc_asthma_2012

# %%
#merged num visits asthma 2009 and cdc 2009
combined_cdc_asthma_2009 = pd.merge(final_cdc_df_2009, numvisits_byfips_2009_df, on="countyfips")

combined_cdc_asthma_2009
